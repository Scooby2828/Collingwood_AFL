# %%
import pandas as pd

# %%
data = pd.read_csv('Collingwood Stats 2025 AFL season.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0  Disposals  Kicks  Handballs  Inside 50's  tackles  marks  \
# 0           0      352.0  209.0      143.0         55.0     39.0   87.0
# 1           1      388.0  223.0      165.0         65.0     69.0   91.0
# 2           2      364.0  204.0      160.0         50.0     64.0   77.0
# 3           3        NaN    NaN        NaN          NaN      NaN    NaN
# 4           4      360.0  193.0      167.0         57.0     85.0   68.0
# 5           5      363.0  206.0      157.0         55.0     72.0   85.0
# 6           6       33.0  195.0      138.0         51.0     33.0   86.0
# 7           7      375.0  221.0      154.0         59.0     62.0   95.0
# 8           8      352.0  218.0      134.0         53.0     64.0  108.0
# 9           9      300.0  190.0      110.0         34.0     66.0   94.0
#
#    contested possesions  uncontested possessions  turnovers  hitouts   \
# 0                 139.0                    200.0       64.0      47.0
# ...

# %%
#Remove 'Unnamed' column
#Convert W/L into numeric values using one hot encoding

# %%
#Remove 'Bye' rounds (NaN rows)
data1=data.drop(index=[3, 14])

# %%
data1.groupby(['Result'])[['tackles']].mean()
# Out:
#           tackles
# Result
# L       65.428571
# W       64.312500
